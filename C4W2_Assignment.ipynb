# %% [markdown]
# # Week 2 Assignment: CIFAR-10 Autoencoder
#
# For this week, you will create a convolutional autoencoder for the [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset. You are free to choose the architecture of your autoencoder provided that the output image has the same dimensions as the input image.
#
# After training, your model should meet loss and accuracy requirements when evaluated with the test dataset. You will then download the model and upload it in the classroom for grading.
#
# Let's begin!

# %% [markdown]
# ***Important:*** *This colab notebook has read-only access so you won't be able to save your changes. If you want to save your work periodically, please click `File -> Save a Copy in Drive` to create a copy in your account, then work from there.*

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import Sequential

# %% [markdown]
# ## Load and prepare the dataset
#
# The [CIFAR 10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset already has train and test splits and you can use those in this exercise. Here are the general steps:
#
# * Load the train/test split from TFDS. Set `as_supervised` to `True` so it will be convenient to use the preprocessing function we provided.
# * Normalize the pixel values to the range [0,1], then return `image, image` pairs for training instead of `image, label`. This is because you will check if the output image is successfully regenerated after going through your autoencoder.
# * Shuffle and batch the train set. Batch the test set (no need to shuffle).

# %%
# preprocessing function
def map_image(image, label):
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0

  return image, image # dataset label is not used. replaced with the same image input.

# parameters
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024


### START CODE HERE (Replace instances of `None` with your code) ###

# use tfds.load() to fetch the 'train' split of CIFAR-10
train_dataset = tfds.load('cifar10', as_supervised=True, split="train")

# preprocess the dataset with the `map_image()` function above
train_dataset = train_dataset.map(map_image)

# shuffle and batch the dataset
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)



# use tfds.load() to fetch the 'test' split of CIFAR-10
test_dataset = tfds.load('cifar10', as_supervised=True, split="test")

# preprocess the dataset with the `map_image()` function above
test_dataset = test_dataset.map(map_image)

# batch the dataset
test_dataset = test_dataset.batch(BATCH_SIZE)

### END CODE HERE ###
# Out:
# Downloading and preparing dataset cifar10/3.0.2 (download: 162.17 MiB, generated: 132.40 MiB, total: 294.58 MiB) to /root/tensorflow_datasets/cifar10/3.0.2...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete5J9LK2/cifar10-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.2.incomplete5J9LK2/cifar10-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ## Build the Model
#
# Create the autoencoder model. As shown in the lectures, you will want to downsample the image in the encoder layers then upsample it in the decoder path. Note that the output layer should be the same dimensions as the original image. Your input images will have the shape `(32, 32, 3)`. If you deviate from this, your model may not be recognized by the grader and may fail.
#
# We included a few hints to use the Sequential API below but feel free to remove it and use the Functional API just like in the ungraded labs if you're more comfortable with it. Another reason to use the latter is if you want to visualize the encoder output. As shown in the ungraded labs, it will be easier to indicate multiple outputs with the Functional API. That is not required for this assignment though so you can just stack layers sequentially if you want a simpler solution.

# %%
# suggested layers to use. feel free to add or remove as you see fit.
from keras.layers import Conv2D, UpSampling2D,MaxPooling2D,Dropout

# use the Sequential API (you can remove if you want to use the Functional API)
model = Sequential()

### START CODE HERE ###
# use `model.add()` to add layers (if using the Sequential API
model.add(Conv2D(64,input_shape=(32,32,3),kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(256,kernel_size=(3,3),activation='relu',padding='same'))

model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='same'))
model.add(UpSampling2D(size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu',padding='same'))
model.add(UpSampling2D(size=(2,2)))


model.add(Conv2D(3,kernel_size=(3,3),activation='sigmoid',padding='same'))








### END CODE HERE ###

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 128)         295040
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 64)        73792
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 32, 32, 3)         1731
# =================================================================
# Total params: 741,379
# Trainable params: 741,379
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Configure training parameters
#
# We have already provided the optimizer, metrics, and loss in the code below.

# %%
# Please do not change the model.compile() parameters
model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')

# %% [markdown]
# ## Training
#
# You can now use [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method) to train your model. You will pass in the `train_dataset` and you are free to configure the other parameters. As with any training, you should see the loss generally going down and the accuracy going up with each epoch. If not, please revisit the previous sections to find possible bugs.

# %%
# parameters
train_steps = len(train_dataset) // BATCH_SIZE 
val_steps = len(test_dataset) // BATCH_SIZE

### START CODE HERE ###
model.fit(train_dataset,steps_per_epoch=train_steps,batch_size=128,validation_data=test_dataset,validation_steps=val_steps,epochs=100)
### END CODE HERE ###
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 104ms/step - loss: 0.0651 - accuracy: 0.4526
# Epoch 2/100
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0607 - accuracy: 0.3360
# Epoch 3/100
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0535 - accuracy: 0.4252
# Epoch 4/100
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0446 - accuracy: 0.5344
# Epoch 5/100
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0349 - accuracy: 0.5145
# Epoch 6/100
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0315 - accuracy: 0.4439
# Epoch 7/100
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0269 - accuracy: 0.5599
# Epoch 8/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0246 - accuracy: 0.6153
# Epoch 9/100
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0211 - accuracy: 0.5940
# Epoch 10/100
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0184 - accuracy: 0.5870
# Epoch 11/100
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0170 - accuracy: 0.6299
# Epoch 12/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0148 - accuracy: 0.6345
# Epoch 13/100
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0195 - accuracy: 0.6214
# Epoch 14/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0164 - accuracy: 0.6437
# Epoch 15/100
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0152 - accuracy: 0.6463
# Epoch 16/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0154 - accuracy: 0.6335
# Epoch 17/100
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0142 - accuracy: 0.6099
# Epoch 18/100
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0138 - accuracy: 0.6271
# Epoch 19/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0126 - accuracy: 0.6582
# Epoch 20/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0122 - accuracy: 0.6675
# Epoch 21/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - accuracy: 0.6395
# Epoch 22/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0108 - accuracy: 0.6336
# Epoch 23/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0106 - accuracy: 0.6646
# Epoch 24/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0106 - accuracy: 0.6392
# Epoch 25/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0106 - accuracy: 0.6565
# Epoch 26/100
# 3/3 [==============================] - 0s 138ms/step - loss: 0.0107 - accuracy: 0.6644
# Epoch 27/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0098 - accuracy: 0.6405
# Epoch 28/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0096 - accuracy: 0.6855
# Epoch 29/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0095 - accuracy: 0.6797
# Epoch 30/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0093 - accuracy: 0.6661
# Epoch 31/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0097 - accuracy: 0.6751
# Epoch 32/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0090 - accuracy: 0.6576
# Epoch 33/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0092 - accuracy: 0.7043
# Epoch 34/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0084 - accuracy: 0.7103
# Epoch 35/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0080 - accuracy: 0.7125
# Epoch 36/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0088 - accuracy: 0.7210
# Epoch 37/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0081 - accuracy: 0.7229
# Epoch 38/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0081 - accuracy: 0.7104
# Epoch 39/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0078 - accuracy: 0.7542
# Epoch 40/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0078 - accuracy: 0.7312
# Epoch 41/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0080 - accuracy: 0.7164
# Epoch 42/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0080 - accuracy: 0.7360
# Epoch 43/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0071 - accuracy: 0.7455
# Epoch 44/100
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0071 - accuracy: 0.7374
# Epoch 45/100
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0067 - accuracy: 0.7677
# Epoch 46/100
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0072 - accuracy: 0.7563
# Epoch 47/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0085 - accuracy: 0.7623
# Epoch 48/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0075 - accuracy: 0.7506
# Epoch 49/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0072 - accuracy: 0.7569
# Epoch 50/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0069 - accuracy: 0.7635
# Epoch 51/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0066 - accuracy: 0.7588
# Epoch 52/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0065 - accuracy: 0.7663
# Epoch 53/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0066 - accuracy: 0.7696
# Epoch 54/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0064 - accuracy: 0.7586
# Epoch 55/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0062 - accuracy: 0.7705
# Epoch 56/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0064 - accuracy: 0.7608
# Epoch 57/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0061 - accuracy: 0.7821
# Epoch 58/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0074 - accuracy: 0.7687
# Epoch 59/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0078 - accuracy: 0.7699
# Epoch 60/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0070 - accuracy: 0.7754
# Epoch 61/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0068 - accuracy: 0.7539
# Epoch 62/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0062 - accuracy: 0.7714
# Epoch 63/100
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0062 - accuracy: 0.7702
# Epoch 64/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0061 - accuracy: 0.7742
# Epoch 65/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0060 - accuracy: 0.7778
# Epoch 66/100
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0066 - accuracy: 0.7697
# Epoch 67/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0059 - accuracy: 0.7808
# Epoch 68/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0058 - accuracy: 0.7937
# Epoch 69/100
# 3/3 [==============================] - 0s 136ms/step - loss: 0.0057 - accuracy: 0.7614
# Epoch 70/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0059 - accuracy: 0.7688
# Epoch 71/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0057 - accuracy: 0.7812
# Epoch 72/100
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0056 - accuracy: 0.7917
# Epoch 73/100
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0058 - accuracy: 0.7721
# Epoch 74/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0059 - accuracy: 0.7768
# Epoch 75/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0057 - accuracy: 0.7769
# Epoch 76/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0057 - accuracy: 0.7773
# Epoch 77/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0053 - accuracy: 0.7711
# Epoch 78/100
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0058 - accuracy: 0.7767
# Epoch 79/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0066 - accuracy: 0.7927
# Epoch 80/100
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0057 - accuracy: 0.7855
# Epoch 81/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0055 - accuracy: 0.7890
# Epoch 82/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0053 - accuracy: 0.7764
# Epoch 83/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0052 - accuracy: 0.7862
# Epoch 84/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0052 - accuracy: 0.7755
# Epoch 85/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0053 - accuracy: 0.7780
# Epoch 86/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0052 - accuracy: 0.7889
# Epoch 87/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0054 - accuracy: 0.7989
# Epoch 88/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0052 - accuracy: 0.7949
# Epoch 89/100
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0051 - accuracy: 0.7900
# Epoch 90/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0055 - accuracy: 0.7833
# Epoch 91/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0054 - accuracy: 0.8009
# Epoch 92/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0050 - accuracy: 0.7840
# Epoch 93/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0051 - accuracy: 0.7885
# Epoch 94/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0050 - accuracy: 0.7720
# Epoch 95/100
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0048 - accuracy: 0.7939
# Epoch 96/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.0048 - accuracy: 0.8009
# Epoch 97/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0064 - accuracy: 0.7799
# Epoch 98/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0069 - accuracy: 0.7918
# Epoch 99/100
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0061 - accuracy: 0.7861
# Epoch 100/100
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0052 - accuracy: 0.7844

# %% [markdown]
# ## Model evaluation
#
# You can use this code to test your model locally before uploading to the grader. To pass, your model needs to satisfy these two requirements:
#
# * loss must be less than 0.01
# * accuracy must be greater than 0.6

# %%
result = model.evaluate(test_dataset, steps=10)
# Out:
# 10/10 [==============================] - 1s 31ms/step - loss: 0.0049 - accuracy: 0.7881

# %% [markdown]
# If you did some visualization like in the ungraded labs, then you might see something like the gallery below. This part is not required.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=12Fy-guiP-3tTPfc9IV2nHhqLvs7LwRo6" width="75%" height="75%"/>

# %% [markdown]
# ## Save your model
#
# Once you are satisfied with the results, you can now save your model. Please download it from the Files window on the left and go back to the Submission portal in Coursera for grading.

# %%
model.save('mymodel.h5')

# %% [markdown]
# **Congratulations on completing this week's assignment!**
